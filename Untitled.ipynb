# %%
texto = """You are a helpful.
        User: what is life
        Assistant: It is interesting
        User: what do you do?"""

# %%
for i in range(10):
    if i == 3:
        break
    else:
        print (i)
# Out:
# 0
# 1
# 2
